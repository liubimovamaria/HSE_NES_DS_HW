# %% [markdown]
# # **UML - диаграмма**

# %% [markdown]
# ![5280800915252700777.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Реализация**

# %%
class Driver:
    '''
    Класс, определяющий водителя
    '''
    id: int
    surname: str
    name: str
    ratio_number: int

    def __init__(self, id, surname, name, number):
        self.id = id
        self.surname = surname
        self.name = name
        self.ratio_number = number

# %%
class Car:
    '''
    Класс, определяющий машину
    '''
    coord: tuple
    gps: str
    person: Driver
    car_type: str

    def __init__(self, coord, gps, person, car_type):
        self.coord = coord
        self.gps = gps
        self.person = person
        self.car_type = car_type

# %%
class Operator:
    '''
    Класс, определяющий оператора и контролирующий все остальные объекты
    '''
    all_drivers: list[Driver]
    all_cars: list[Car]

    def __init__(self):
        self.all_cars = []
        self.all_drivers = []

    def repair(self, car):
        '''
        Метод, который отправляет машину на ремонт
        '''
        pass

    def give_task(car, driver):
        '''
        Метод, который сажает водителя за руль машины
        '''
        pass

    def end_work(driver):
        '''
        Метод, который отмечает, что водитель закончил пользование автомобилем
        '''
        pass

# %%
class MiningTrack(Car):
    '''
    Класс, определяющий первый тип машин - карьерные самосвалы
    '''
    load_capacity: str
    brand: str
    model: str

    def __init__(self, load_capacity, brand, model):
        super().__init__()
        self.load_capacity = load_capacity
        self.brand = brand
        self.model = model

    def transport(self):
        '''
        Метод для перевозки материала
        '''
        pass

# %%
class SimpleTrack(Car):
    '''
    Класс, определяющий второй тип машин - обычные самосвалы
    '''
    load: str
    brand: str

    def __init__(self, load, brand):
        super().__init__()
        self.load = load
        self.brand = brand

    def transport(self):
        '''
        Метод для перевозки различных деталей и предметов
        '''
        pass

# %%
class Official(Car):
    '''
    Класс, определяющий третий тип машин - служебные машины
    '''
    def operative_ride(self):
        '''
        Метод для оперативной поездки
        '''
        pass
